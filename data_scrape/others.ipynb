# %%
# Run this cell to import required libraries

from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scraping Student-Clubs site

# %%
data_url = "https://sites.duke.edu/prattgsps/student-clubs/"
page = requests.get(data_url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# Find all elements with the class "elementor-widget-container"
elements = soup.find_all(class_="elementor-widget-container")

# # Loop through and print the elements
# i = 0
# for element in elements:
#     print(i)
#     print(element)
#     print("__________________________________")
#     i += 1
student_clubs_html = elements[6].find_all('p')
activities = {}
for student_club in student_clubs_html:
    text = student_club.get_text()
    activities[text.split(" Club")[0]] = text
activities
# Out:
# {'Badminton': 'Badminton Club offers a weekly opportunity for students to play badminton and network with others.\xa0 Whether you are new to the sport or highly skilled, everyone is welcome. All equipment is provided.',
#  'Bean Together Coffee': 'Bean Together Coffee Club fosters wellness and community-building by hosting coffee events. By exploring coffee’s many flavors and permutations as a group, and by structuring our events around poetry recitation, discussion topics, and other community-building techniques, we will encourage attendees to develop new friendships and improve their mental well-being.',
#  'Dance': 'Dance Club unites the members of the engineering community through different types of dance from a wide range of cultures and backgrounds.',
#  'Diversity and Culture': 'Diversity and Culture Club seeks to connect students, faculty, and staff from all different backgrounds and engineering concentrations with exciting social events celebrating various cultures.\xa0 The club also seeks to foster awareness of diversity in STEM\xa0 through education and empowerment.',
#  'Media': 'Media Club engages our students interested in expressing themselves through photography and cinematography. Participants can attend photo editing workshops, learn techniques, and collaborate with others on fun photography projects. No experience or special equipment needed. They love to remind you that the “best” camera is the one you have with you. Learn more here.',
#  'Sports': 'Sports Club provides a safe and inclusive community where students can participate in sports and physical activities that enhance their personal, social, and physical well-being. They aim to foster a sense of belonging and teamwork through sports, and to create opportunities for skill development, competition, and leadership. Learn more here.',
#  'Sustainability': 'Sustainability Club aims to inspire and engage master’s community in making positive changes for the environment and future generations by promoting awareness and education on all aspects of sustainability, including relevant topics in climate tech and the growing career opportunities within this field.'}

# %%
activities_df = pd.DataFrame(list(activities.items()), columns=['Name', 'Description'])

# %%
activities_df["Type"] = "Club"
activities_df["Reference"] = "https://sites.duke.edu/prattgsps/student-clubs/"

# %%
activities_df
# Out:
#                     Name                                        Description  \
# 0              Badminton  Badminton Club offers a weekly opportunity for...
# 1   Bean Together Coffee  Bean Together Coffee Club fosters wellness and...
# 2                  Dance  Dance Club unites the members of the engineeri...
# 3  Diversity and Culture  Diversity and Culture Club seeks to connect st...
# 4                  Media  Media Club engages our students interested in ...
# 5                 Sports  Sports Club provides a safe and inclusive comm...
# 6         Sustainability  Sustainability Club aims to inspire and engage...
#
#    Type                                        Reference
# 0  Club  https://sites.duke.edu/prattgsps/student-clubs/
# 1  Club  https://sites.duke.edu/prattgsps/student-clubs/
# 2  Club  https://sites.duke.edu/prattgsps/student-clubs/
# 3  Club  https://sites.duke.edu/prattgsps/student-clubs/
# 4  Club  https://sites.duke.edu/prattgsps/student-clubs/
# 5  Club  https://sites.duke.edu/prattgsps/student-clubs/
# 6  Club  https://sites.duke.edu/prattgsps/student-clubs/

# %% [markdown]
# ## Scraping Student Advisory Board

# %%
data_url = "https://sites.duke.edu/prattgsps/engineering-masters-programs-student-advisory-board/"
page = requests.get(data_url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# Find all elements with the class "elementor-widget-container"
elements = soup.find_all(class_="elementor-widget-container")

# # Loop through and print the elements
# i = 0
# for element in elements:
#     print(i)
#     print(element)
#     print("__________________________________")
#     i += 1
desc = elements[1].find('p')
description = desc.get_text()

# %%
# Create a dictionary for the advisory board
advisory_board = {
    "Name": ["Engineering Master’s Programs Student Advisory Board"],
    "Description": [description],
    "Type": ["Board"],
    "Reference": ["https://sites.duke.edu/prattgsps/engineering-masters-programs-student-advisory-board/"]
}

# Convert the dictionary to a DataFrame
advisory_board_df = pd.DataFrame(advisory_board)

# Print the DataFrame
advisory_board_df
# Out:
#                                                 Name  \
# 0  Engineering Master’s Programs Student Advisory...
#
#                                          Description   Type  \
# 0  The Engineering Master’s Programs Student Advi...  Board
#
#                                            Reference
# 0  https://sites.duke.edu/prattgsps/engineering-m...

# %%
activities_df = pd.concat([activities_df, advisory_board_df], ignore_index = True)

# %% [markdown]
# ## Commities

# %%
data_url = "https://gpsg.duke.edu/committees/"
page = requests.get(data_url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
elements = soup.find_all(class_="entry-content clear")
elements[0].find_all('h3')
# Out:
# [<h3>Standing Committees</h3>,
#  <h3>Climate Crisis Committee (CCC)</h3>,
#  <h3>Diversity, Equity, and Inclusion Committee (DEI)</h3>,
#  <h3>GPSG CAN</h3>,
#  <h3>Doctoral Student Affairs Committee (DSA)</h3>,
#  <h3>External Advocacy Committee (EAC)</h3>,
#  <h3>Parking and Transportation Committee (P&amp;T)</h3>,
#  <h3>Rules Committee</h3>,
#  <h3>International Student Affairs Committee (ISA)</h3>,
#  <h3>Events Programming Committee</h3>,
#  <h3>GPSG Community Pantry</h3>,
#  <h3>GPSG Assembly</h3>]

# %%
# Initialize a dictionary to store the committee information
committee_info = {}

# Find all the <h3> tags that contain committee names
committee_names = elements[0].find_all('h3')
# Loop through the <h3> tags to extract committee information
for h3 in committee_names[1:]:
    committee_name = h3.text.strip()
    # Find the <p> tag immediately following the <h3> tag
    p_tag = h3.find_next('p')
    if p_tag:
        committee_description = p_tag.text.strip()
        # Add the committee name and description to the dictionary
        committee_info[committee_name] = committee_description

# Print the dictionary
print(committee_info)
# Out:
# {'Climate Crisis Committee (CCC)': 'If you want to see a truly green Duke University, join GPSG’s Climate Crisis Committee! We work on issues all across campus like divesting our endowment from fossil fuels, improving mental health resources to cope with climate change, advancing environmental justice commitments, and reducing waste from graduate and professional programs. Join us to help us build a more sustainable and equitable future!', 'Diversity, Equity, and Inclusion Committee (DEI)': 'The GPSG DEI Committee is tasked with identifying ways to continuously promote diversity, equity, and inclusion on campus. One major way this is accomplished is through connecting with DEI leaders across campus, be they students, faculty, or staff. Members of the DEI Committee work to impart meaningful change on campus through conversations with administration, passing key resolutions through the GPSG assembly, and collaboration with other student groups both within and without the GPSG body. As issues of Diversity, Equity, and Inclusion can touch many aspects of student life, the DEI Committee is open to approach about any topic.', 'GPSG CAN': 'GPSG CAN is the Duke University graduate and professional student chapter of Durham CAN, focused on broad-based advocacy in the Durham area.', 'Doctoral Student Affairs Committee (DSA)': 'The Doctoral Student Affairs Committee is tasked with addressing campus-wide issues that affect doctoral students.', 'External Advocacy Committee (EAC)': 'The External Advocacy Committee is tasked with organizing GPSG’s advocacy efforts at the state and federal levels, including voter registration, communicating issues to state and federal legislators, and engaging with student advocates at other institutions of higher education. Committee members are invited to participate in an annual trip to DC to speak with federal lawmakers and their staff.', 'Parking and Transportation Committee (P&T)': 'The Parking and Transportation Committee is tasked with addressing issues of parking and transit at Duke University and in the Durham area.', 'Rules Committee': 'The Rules Committee is tasked with maintaining GPSG’s constitution, bylaws, and standing rules of order, addressing questions about GPSG operating rules, receiving complaints, and adjudicating disputes.', 'International Student Affairs Committee (ISA)': 'The International Student Affairs Committee is tasked with advocating for the concerns of graduate and professional international students on campus.', 'Events Programming Committee': 'The GPSG Director of Events Programming is charged with hosting social programming available to all graduate and professional students.', 'GPSG Community Pantry': 'This is not a standing committee, but the Community Pantry is a service of GPSG that provides non-perishable foods and meals to graduate and professional students struggling with food insecurity.', 'GPSG Assembly': 'This is not a standing committee, but the Assembly is the legislative branch of GPSG. All Duke graduate and professional students are automatically members of the Assembly and may attend any and all Assembly meetings to listen in and bring up topics for discussion with representatives from every graduate and professional school and program at Duke. Assembly meetings occur every other Tuesday, 6:30pm – 8:30pm ET over Zoom.'}

# %%
committees_df = pd.DataFrame(list(committee_info.items()), columns=['Name', 'Description'])
committees_df["Type"] = "Committee"
committees_df["Reference"] = "https://gpsg.duke.edu/committees/"
committees_df
# Out:
#                                                 Name  \
# 0                     Climate Crisis Committee (CCC)
# 1   Diversity, Equity, and Inclusion Committee (DEI)
# 2                                           GPSG CAN
# 3           Doctoral Student Affairs Committee (DSA)
# 4                  External Advocacy Committee (EAC)
# 5         Parking and Transportation Committee (P&T)
# 6                                    Rules Committee
# 7      International Student Affairs Committee (ISA)
# 8                       Events Programming Committee
# 9                              GPSG Community Pantry
# 10                                     GPSG Assembly
#
#                                           Description       Type  \
# 0   If you want to see a truly green Duke Universi...  Committee
# 1   The GPSG DEI Committee is tasked with identify...  Committee
# 2   GPSG CAN is the Duke University graduate and p...  Committee
# 3   The Doctoral Student Affairs Committee is task...  Committee
# 4   The External Advocacy Committee is tasked with...  Committee
# 5   The Parking and Transportation Committee is ta...  Committee
# 6   The Rules Committee is tasked with maintaining...  Committee
# 7   The International Student Affairs Committee is...  Committee
# 8   The GPSG Director of Events Programming is cha...  Committee
# 9   This is not a standing committee, but the Comm...  Committee
# 10  This is not a standing committee, but the Asse...  Committee
#
#                             Reference
# 0   https://gpsg.duke.edu/committees/
# 1   https://gpsg.duke.edu/committees/
# 2   https://gpsg.duke.edu/committees/
# 3   https://gpsg.duke.edu/committees/
# 4   https://gpsg.duke.edu/committees/
# 5   https://gpsg.duke.edu/committees/
# 6   https://gpsg.duke.edu/committees/
# 7   https://gpsg.duke.edu/committees/
# 8   https://gpsg.duke.edu/committees/
# 9   https://gpsg.duke.edu/committees/
# 10  https://gpsg.duke.edu/committees/

# %%
activities_df = pd.concat([activities_df, committees_df], ignore_index = True)
activities_df
# Out:
#                                                  Name  \
# 0                                           Badminton
# 1                                Bean Together Coffee
# 2                                               Dance
# 3                               Diversity and Culture
# 4                                               Media
# 5                                              Sports
# 6                                      Sustainability
# 7   Engineering Master’s Programs Student Advisory...
# 8                      Climate Crisis Committee (CCC)
# 9    Diversity, Equity, and Inclusion Committee (DEI)
# 10                                           GPSG CAN
# 11           Doctoral Student Affairs Committee (DSA)
# 12                  External Advocacy Committee (EAC)
# 13         Parking and Transportation Committee (P&T)
# 14                                    Rules Committee
# 15      International Student Affairs Committee (ISA)
# 16                       Events Programming Committee
# 17                              GPSG Community Pantry
# 18                                      GPSG Assembly
#
#                                           Description       Type  \
# 0   Badminton Club offers a weekly opportunity for...       Club
# 1   Bean Together Coffee Club fosters wellness and...       Club
# 2   Dance Club unites the members of the engineeri...       Club
# 3   Diversity and Culture Club seeks to connect st...       Club
# 4   Media Club engages our students interested in ...       Club
# 5   Sports Club provides a safe and inclusive comm...       Club
# 6   Sustainability Club aims to inspire and engage...       Club
# 7   The Engineering Master’s Programs Student Advi...      Board
# 8   If you want to see a truly green Duke Universi...  Committee
# 9   The GPSG DEI Committee is tasked with identify...  Committee
# 10  GPSG CAN is the Duke University graduate and p...  Committee
# 11  The Doctoral Student Affairs Committee is task...  Committee
# 12  The External Advocacy Committee is tasked with...  Committee
# 13  The Parking and Transportation Committee is ta...  Committee
# 14  The Rules Committee is tasked with maintaining...  Committee
# 15  The International Student Affairs Committee is...  Committee
# 16  The GPSG Director of Events Programming is cha...  Committee
# 17  This is not a standing committee, but the Comm...  Committee
# 18  This is not a standing committee, but the Asse...  Committee
#
#                                             Reference
# 0     https://sites.duke.edu/prattgsps/student-clubs/
# 1     https://sites.duke.edu/prattgsps/student-clubs/
# 2     https://sites.duke.edu/prattgsps/student-clubs/
# 3     https://sites.duke.edu/prattgsps/student-clubs/
# 4     https://sites.duke.edu/prattgsps/student-clubs/
# 5     https://sites.duke.edu/prattgsps/student-clubs/
# 6     https://sites.duke.edu/prattgsps/student-clubs/
# 7   https://sites.duke.edu/prattgsps/engineering-m...
# 8                   https://gpsg.duke.edu/committees/
# 9                   https://gpsg.duke.edu/committees/
# 10                  https://gpsg.duke.edu/committees/
# 11                  https://gpsg.duke.edu/committees/
# 12                  https://gpsg.duke.edu/committees/
# 13                  https://gpsg.duke.edu/committees/
# 14                  https://gpsg.duke.edu/committees/
# 15                  https://gpsg.duke.edu/committees/
# 16                  https://gpsg.duke.edu/committees/
# 17                  https://gpsg.duke.edu/committees/
# 18                  https://gpsg.duke.edu/committees/

# %% [markdown]
# ## More Resources

# %%
add_resources = [{"Name": "Lawyer Assistance Program", "Description": "The GPSG Lawyer Assistance Program provides students with legal counseling, risk reduction, and mitigation of legal issues.", "Type": "Resource", "Reference": "https://gpsg.duke.edu/resources-for-students/lawyer-assistance-program/"},
                    {"Name": "Funding for Student Groups", "Description": "The Duke Graduate and Professional Student Government encourages students to form groups around social, academic, and cultural similarities. To support these groups, the GPSG allocates a large portion of its budget to funding events and materials for these groups.", "Type": "Resource", "Reference": "https://gpsg.duke.edu/resources-for-students/resources-for-student-groups/"}]

# %%
add_resources_df = pd.DataFrame(add_resources)
add_resources_df
# Out:
#                          Name  \
# 0   Lawyer Assistance Program
# 1  Funding for Student Groups
#
#                                          Description      Type  \
# 0  The GPSG Lawyer Assistance Program provides st...  Resource
# 1  The Duke Graduate and Professional Student Gov...  Resource
#
#                                            Reference
# 0  https://gpsg.duke.edu/resources-for-students/l...
# 1  https://gpsg.duke.edu/resources-for-students/r...

# %%
activities_df = pd.concat([activities_df, add_resources_df], ignore_index = True)
activities_df
# Out:
#                                                  Name  \
# 0                                           Badminton
# 1                                Bean Together Coffee
# 2                                               Dance
# 3                               Diversity and Culture
# 4                                               Media
# 5                                              Sports
# 6                                      Sustainability
# 7   Engineering Master’s Programs Student Advisory...
# 8                      Climate Crisis Committee (CCC)
# 9    Diversity, Equity, and Inclusion Committee (DEI)
# 10                                           GPSG CAN
# 11           Doctoral Student Affairs Committee (DSA)
# 12                  External Advocacy Committee (EAC)
# 13         Parking and Transportation Committee (P&T)
# 14                                    Rules Committee
# 15      International Student Affairs Committee (ISA)
# 16                       Events Programming Committee
# 17                              GPSG Community Pantry
# 18                                      GPSG Assembly
# 19                          Lawyer Assistance Program
# 20                         Funding for Student Groups
#
#                                           Description       Type  \
# 0   Badminton Club offers a weekly opportunity for...       Club
# 1   Bean Together Coffee Club fosters wellness and...       Club
# 2   Dance Club unites the members of the engineeri...       Club
# 3   Diversity and Culture Club seeks to connect st...       Club
# 4   Media Club engages our students interested in ...       Club
# 5   Sports Club provides a safe and inclusive comm...       Club
# 6   Sustainability Club aims to inspire and engage...       Club
# 7   The Engineering Master’s Programs Student Advi...      Board
# 8   If you want to see a truly green Duke Universi...  Committee
# 9   The GPSG DEI Committee is tasked with identify...  Committee
# 10  GPSG CAN is the Duke University graduate and p...  Committee
# 11  The Doctoral Student Affairs Committee is task...  Committee
# 12  The External Advocacy Committee is tasked with...  Committee
# 13  The Parking and Transportation Committee is ta...  Committee
# 14  The Rules Committee is tasked with maintaining...  Committee
# 15  The International Student Affairs Committee is...  Committee
# 16  The GPSG Director of Events Programming is cha...  Committee
# 17  This is not a standing committee, but the Comm...  Committee
# 18  This is not a standing committee, but the Asse...  Committee
# 19  The GPSG Lawyer Assistance Program provides st...   Resource
# 20  The Duke Graduate and Professional Student Gov...   Resource
#
#                                             Reference
# 0     https://sites.duke.edu/prattgsps/student-clubs/
# 1     https://sites.duke.edu/prattgsps/student-clubs/
# 2     https://sites.duke.edu/prattgsps/student-clubs/
# 3     https://sites.duke.edu/prattgsps/student-clubs/
# 4     https://sites.duke.edu/prattgsps/student-clubs/
# 5     https://sites.duke.edu/prattgsps/student-clubs/
# 6     https://sites.duke.edu/prattgsps/student-clubs/
# 7   https://sites.duke.edu/prattgsps/engineering-m...
# 8                   https://gpsg.duke.edu/committees/
# 9                   https://gpsg.duke.edu/committees/
# 10                  https://gpsg.duke.edu/committees/
# 11                  https://gpsg.duke.edu/committees/
# 12                  https://gpsg.duke.edu/committees/
# 13                  https://gpsg.duke.edu/committees/
# 14                  https://gpsg.duke.edu/committees/
# 15                  https://gpsg.duke.edu/committees/
# 16                  https://gpsg.duke.edu/committees/
# 17                  https://gpsg.duke.edu/committees/
# 18                  https://gpsg.duke.edu/committees/
# 19  https://gpsg.duke.edu/resources-for-students/l...
# 20  https://gpsg.duke.edu/resources-for-students/r...

# %%
print(activities_df[activities_df['Name'] == 'GPSG CAN']['Description'])
# Out:
# 10    GPSG CAN is the Duke University graduate and p...
# Name: Description, dtype: object

# %%
# for i in activities_df['Description']:
#     print(i)
#     print("____________________")

# %%
CAPS_resources = [{"Name": "Individual Counseling & Psychiatric Services", 
                  "Description": "Individual counseling provides students the opportunity to meet with a provider and collaboratively work to determine and agree upon goals of treatment in a one-on-one setting. It's part of Counseling and Psychological Services (CAPS)", 
                  "Type": "Service", 
                  "Reference": "https://students.duke.edu/wellness/caps/individual/"
                 },
                 {"Name": "Group Counseling", 
                  "Description": "Our Group Services include group therapy and discussion groups with a variety of goals that aim to promote wellbeing. Research demonstrates that group therapy is equally effective as individual therapy and is often the treatment of choice for student issues. It's part of Counseling and Psychological Services (CAPS)", 
                  "Type": "Service", 
                  "Reference": "https://students.duke.edu/wellness/caps/group/"
                 },
                 {"Name": "Workshops & Discussions", 
                  "Description": "We provide a wide range of interactive, skill-building workshops on various mental health topics for the entire Duke community. It's part of Counseling and Psychological Services (CAPS)", 
                  "Type": "Service", 
                  "Reference": "https://students.duke.edu/wellness/caps/"
                 },
                 {"Name": "Referrals to Community Providers", 
                  "Description": "Our primary goal is to ensure students have access to the best possible care based on their unique needs and sometimes this means working with a professional outside of Counseling and Psychological Services (CAPS). To start, you can meet with our referral coordinator or browse our list of community providers.", 
                  "Type": "Service", 
                  "Reference": "https://duke.miresource.com/"
                 }
                ]

# %%
CAPS_resources_df = pd.DataFrame(CAPS_resources)
CAPS_resources_df
# Out:
#                                            Name  \
# 0  Individual Counseling & Psychiatric Services
# 1                              Group Counseling
# 2                       Workshops & Discussions
# 3              Referrals to Community Providers
#
#                                          Description     Type  \
# 0  Individual counseling provides students the op...  Service
# 1  Our Group Services include group therapy and d...  Service
# 2  We provide a wide range of interactive, skill-...  Service
# 3  Our primary goal is to ensure students have ac...  Service
#
#                                            Reference
# 0  https://students.duke.edu/wellness/caps/indivi...
# 1     https://students.duke.edu/wellness/caps/group/
# 2           https://students.duke.edu/wellness/caps/
# 3                       https://duke.miresource.com/

# %%
activities_df = pd.concat([activities_df, CAPS_resources_df], ignore_index = True)
activities_df
# Out:
#                                                  Name  \
# 0                                           Badminton
# 1                                Bean Together Coffee
# 2                                               Dance
# 3                               Diversity and Culture
# 4                                               Media
# 5                                              Sports
# 6                                      Sustainability
# 7   Engineering Master’s Programs Student Advisory...
# 8                      Climate Crisis Committee (CCC)
# 9    Diversity, Equity, and Inclusion Committee (DEI)
# 10                                           GPSG CAN
# 11           Doctoral Student Affairs Committee (DSA)
# 12                  External Advocacy Committee (EAC)
# 13         Parking and Transportation Committee (P&T)
# 14                                    Rules Committee
# 15      International Student Affairs Committee (ISA)
# 16                       Events Programming Committee
# 17                              GPSG Community Pantry
# 18                                      GPSG Assembly
# 19                          Lawyer Assistance Program
# 20                         Funding for Student Groups
# 21       Individual Counseling & Psychiatric Services
# 22                                   Group Counseling
# 23                            Workshops & Discussions
# 24                   Referrals to Community Providers
#
#                                           Description       Type  \
# 0   Badminton Club offers a weekly opportunity for...       Club
# 1   Bean Together Coffee Club fosters wellness and...       Club
# 2   Dance Club unites the members of the engineeri...       Club
# 3   Diversity and Culture Club seeks to connect st...       Club
# 4   Media Club engages our students interested in ...       Club
# 5   Sports Club provides a safe and inclusive comm...       Club
# 6   Sustainability Club aims to inspire and engage...       Club
# 7   The Engineering Master’s Programs Student Advi...      Board
# 8   If you want to see a truly green Duke Universi...  Committee
# 9   The GPSG DEI Committee is tasked with identify...  Committee
# 10  GPSG CAN is the Duke University graduate and p...  Committee
# 11  The Doctoral Student Affairs Committee is task...  Committee
# 12  The External Advocacy Committee is tasked with...  Committee
# 13  The Parking and Transportation Committee is ta...  Committee
# 14  The Rules Committee is tasked with maintaining...  Committee
# 15  The International Student Affairs Committee is...  Committee
# 16  The GPSG Director of Events Programming is cha...  Committee
# 17  This is not a standing committee, but the Comm...  Committee
# 18  This is not a standing committee, but the Asse...  Committee
# 19  The GPSG Lawyer Assistance Program provides st...   Resource
# 20  The Duke Graduate and Professional Student Gov...   Resource
# 21  Individual counseling provides students the op...    Service
# 22  Our Group Services include group therapy and d...    Service
# 23  We provide a wide range of interactive, skill-...    Service
# 24  Our primary goal is to ensure students have ac...    Service
#
#                                             Reference
# 0     https://sites.duke.edu/prattgsps/student-clubs/
# 1     https://sites.duke.edu/prattgsps/student-clubs/
# 2     https://sites.duke.edu/prattgsps/student-clubs/
# 3     https://sites.duke.edu/prattgsps/student-clubs/
# 4     https://sites.duke.edu/prattgsps/student-clubs/
# 5     https://sites.duke.edu/prattgsps/student-clubs/
# 6     https://sites.duke.edu/prattgsps/student-clubs/
# 7   https://sites.duke.edu/prattgsps/engineering-m...
# 8                   https://gpsg.duke.edu/committees/
# 9                   https://gpsg.duke.edu/committees/
# 10                  https://gpsg.duke.edu/committees/
# 11                  https://gpsg.duke.edu/committees/
# 12                  https://gpsg.duke.edu/committees/
# 13                  https://gpsg.duke.edu/committees/
# 14                  https://gpsg.duke.edu/committees/
# 15                  https://gpsg.duke.edu/committees/
# 16                  https://gpsg.duke.edu/committees/
# 17                  https://gpsg.duke.edu/committees/
# 18                  https://gpsg.duke.edu/committees/
# 19  https://gpsg.duke.edu/resources-for-students/l...
# 20  https://gpsg.duke.edu/resources-for-students/r...
# 21  https://students.duke.edu/wellness/caps/indivi...
# 22     https://students.duke.edu/wellness/caps/group/
# 23           https://students.duke.edu/wellness/caps/
# 24                       https://duke.miresource.com/

# %%
duke_groups_df = pd.read_csv("data_groups.csv", encoding='latin-1')
duke_groups_df
# Out:
#                                   title  \
# 0                       Academic Guides
# 1              Academic Resource Center
# 2                         Acts2 at Duke
# 3                   Adopt A Grandparent
# 4    AgapÃ© Campus Christian Fellowship
# ..                                  ...
# 578                      The Pitchforks
# 579                     The Poetea Club
# 580  The UNICEF Club at Duke University
# 581                       The Wild Ones
# 582                 The Women's Network
#
#                                           link  \
# 0       https://dukegroups.com/AcademicGuides/
# 1                        https://arc.duke.edu/
# 2                http://www.acts2oncampus.org/
# 3               https://sites.duke.edu/dukeaag
# 4           http://www.agapeharvestchurch.org/
# ..                                         ...
# 578             http://www.dukepitchforks.com/
# 579             https://dukegroups.com/Poetea/
# 580             https://dukegroups.com/UNICEF/
# 581  https://www.instagram.com/duke_wild_ones/
# 582                https://dukegroups.com/TWN/
#
#                                                mission
# 0    We are members of the undergraduate community'...
# 1    We know you are already smart, but why stop th...
# 2    Were a campus fellowship committed to followi...
# 3    Adopt a Grandparent is a student community ser...
# 4    To provide undergrad and graduate students at ...
# ..                                                 ...
# 578  The Pitchforks are first and foremost a TTBB, ...
# 579                                                NaN
# 580  The mission of this organization will be to ab...
# 581  The mission of The Wild Ones is to provide und...
# 582                                                NaN
#
# [583 rows x 3 columns]

# %%
duke_groups_df[duke_groups_df.mission.isna()]
# Out:
#                              title                                link mission
# 24           Bassett House Council     https://dukegroups.com/Bassett/     NaN
# 26        Bell Tower House Council        https://dukegroups.com/Bell/     NaN
# 32   Black Pre-Law Society at Duke       https://dukegroups.com/DBPLS/     NaN
# 35         Blackwell House Council   https://dukegroups.com/Blackwell/     NaN
# 36         Blue Angels Greek Dance     https://dukegroups.com/Angeloi/     NaN
# ..                             ...                                 ...     ...
# 570                       The Flow            https://theflowduke.com/     NaN
# 572      The Fouling Community LLC  https://dukegroups.com/foulingllc/     NaN
# 575                     The Lyceum      https://dukegroups.com/Lyceum/     NaN
# 579                The Poetea Club      https://dukegroups.com/Poetea/     NaN
# 582            The Women's Network         https://dukegroups.com/TWN/     NaN
#
# [226 rows x 3 columns]

# %%
# Assuming duke_groups_df is your DataFrame
duke_groups_starting_df = duke_groups_df[duke_groups_df['link'].str.startswith('https://dukegroups.com/')]
duke_groups_starting_df = duke_groups_starting_df[duke_groups_starting_df.mission.isna()]
duke_groups_starting_df
# Out:
#                              title                                  link  \
# 24           Bassett House Council       https://dukegroups.com/Bassett/
# 26        Bell Tower House Council          https://dukegroups.com/Bell/
# 32   Black Pre-Law Society at Duke         https://dukegroups.com/DBPLS/
# 35         Blackwell House Council     https://dukegroups.com/Blackwell/
# 36         Blue Angels Greek Dance       https://dukegroups.com/Angeloi/
# ..                             ...                                   ...
# 564                  The Chronicle  https://dukegroups.com/TheChronicle/
# 572      The Fouling Community LLC    https://dukegroups.com/foulingllc/
# 575                     The Lyceum        https://dukegroups.com/Lyceum/
# 579                The Poetea Club        https://dukegroups.com/Poetea/
# 582            The Women's Network           https://dukegroups.com/TWN/
#
#     mission
# 24      NaN
# 26      NaN
# 32      NaN
# 35      NaN
# 36      NaN
# ..      ...
# 564     NaN
# 572     NaN
# 575     NaN
# 579     NaN
# 582     NaN
#
# [157 rows x 3 columns]

# %%
def mission_from_link(x):
    print(x)
    test_url = x
    test_page = requests.get(test_url)
    test_soup = BeautifulSoup(test_page.content, 'html.parser')
    elements = test_soup.find_all(class_="col-sm-10 col-md-8")
    if elements:
        mission_statement = elements[0].find('p')
        text = mission_statement.get_text().strip().replaceAll("[\\t\\n\\r]+"," ")
        if text == 'Our mission is (fill in your mission here...)':
            return "To know about it, reach out to people from the reference link."
        return text
    else:
        return "To know about it, reach out to people from the reference link."


duke_groups_starting_df['mission'] = duke_groups_starting_df['link'].apply(mission_from_link)
duke_groups_starting_df
# Out:
# https://dukegroups.com/Bassett/
# https://dukegroups.com/Bell/
# https://dukegroups.com/DBPLS/
# https://dukegroups.com/Blackwell/
# https://dukegroups.com/Angeloi/
# https://dukegroups.com/boostbeyond/
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 17
#      13     else:
#      14         return "To know about it, reach out to people from the reference link."
# ---> 17 duke_groups_starting_df['mission'] = duke_groups_starting_df['link'].apply(mission_from_link)
#      18 duke_groups_starting_df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[98], line 9, in mission_from_link(x)
#       7 if elements:
#       8     mission_statement = elements[0].find('p')
# ----> 9     text = mission_statement.get_text().strip().replaceAll("[\\t\\n\\r]+"," ")
#      10     if text == 'Our mission is (fill in your mission here...)':
#      11         return "To know about it, reach out to people from the reference link."
#
# AttributeError: 'str' object has no attribute 'replaceAll'

# %%
duke_groups_starting_df

# %%
set(duke_groups_starting_df.mission)
